# %% [markdown]
# <a href="https://colab.research.google.com/github/MaitreePimple/Data-Science/blob/main/DAY3(matplotlib).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
values = [5,6,3,7,2]
names = ["A","B","C","D","E"]
plt.bar(names,values,color="#C8A2C8")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data
x = np.array(["A", "B", "C", "D", "E"])
y = np.array([10, 20, 30, 40, 50])

# Define a list of colors for each bar
colors = ["red", "green", "blue", "yellow", "purple"]

# Create the bar chart
plt.bar(x, y, color=colors)

# Add title and axis labels
plt.title("Bar Chart with Different Colors")
plt.xlabel("Category")
plt.ylabel("Value")

# Show the chart
plt.show()

# %%
ages=[6,7,8,23,24,25,26,34,56,45,24,23,45,45,56]
range=(0,100)
bins=15
plt.hist(ages,bins,range,color='purple',histtype='bar',edgecolor='black',alpha=0.9)
plt.show()

# %%
import matplotlib.pyplot as plt
x_values = [0,1,2,3,4,5]
y_values = [0,1,4,9,16,25]

plt.scatter(x,y,label="stars",color="blue",marker="s",s=30)
plt.show()

# %%
import matplotlib.pyplot as plt
activities = ['eat','sleep','work','play']
slices=[3,7,8,6]
colors = ['r','y','g','b']
plt.pie(slices,labels = activities, colors=colors, startangle=90,shadow =True, explode =
        (0,0,0.1,0),radius = 1.2, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x795e1c076ec0>,
# ...
#  [Text(-0.5051421307219185, 1.2195209829148985, 'eat'),
#   Text(-1.3087072223905565, -0.17229453288713012, 'sleep'),
#   Text(0.709999961620642, -1.2297560955322349, 'work'),
#   Text(0.933380951166243, 0.9333809511662425, 'play')],
#  [Text(-0.2755320713028646, 0.6651932634081265, '12.5%'),
#   Text(-0.7138403031221217, -0.09397883612025279, '29.2%'),
#   Text(0.40999997783727216, -0.7101408438988961, '33.3%'),
#   Text(0.5091168824543143, 0.5091168824543141, '25.0%')])

# %%
import matplotlib.pyplot as plt
x_values=[0,1,2,3,4,5]
y_values=[0,1,4,9,16,25]
plt.plot(x_values,y_values)
plt.title("square numbers")
plt.xlabel("value")
plt.ylabel("square of numbers")
plt.show()

# %%
x1=[1,2,3,4]
y1=[4,6,7,8]
plt.plot(x1,y1,label='line1')
x2=[7,8,9,6]
y2=[5,6,6,8]
plt.plot(x2,y2,label='line2')
plt.legend()
plt.show()
